# %%
from datetime import datetime
import json
import gc
import pandas as pd
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, roc_curve
from flaml import AutoML
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import pickle
import re

# %%
# Obtener la fecha actual
fecha_actual = datetime.now().strftime("%Y%m%d")

# %%
# Definir función para cargar datos en partes y reducir memoria
def load_data_in_chunks(file_path, chunk_size=100000):
    chunk_list = []
    try:
        for chunk in pd.read_parquet(file_path, chunksize=chunk_size):
            chunk_list.append(chunk)
    except MemoryError:
        print(f"Memory error occurred while reading {file_path}.")
        return None
    return pd.concat(chunk_list)

# Reducción de tipo de datos
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print(f"Memory usage of dataframe is {start_mem:.2f} MB")
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                else:
                    df[col] = df[col].astype(np.int64)
            else:
                df[col] = df[col].astype(np.float32)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print(f"Memory usage after optimization is: {end_mem:.2f} MB")
    print(f"Decreased by {(start_mem - end_mem) / start_mem * 100:.1f}%")
    return df

# %%
# Leer el archivo de control
with open('control_config.json', 'r') as f:
    config = json.load(f)

# %%
# Función para limpiar nombres de las columnas
def clean_column_names(df):
    df.columns = [re.sub(r'[^A-Za-z0-9_]', '', col) for col in df.columns]
    return df

# %%
# Definir las variantes de normalización
variantes = ['No_Norm', 'MinMax', 'Std', 'Maxabs', 'Robust']  # Lista de variantes a considerar

# Almacenar resultados para cada variante
resultados = {}

# %%
for variante in variantes:
    # Cargar los conjuntos de datos específicos de la variante
    X_train = pd.read_parquet(config['data_paths'][f'X_train_{variante}'])
    X_test = pd.read_parquet(config['data_paths'][f'X_test_{variante}'])
    y_train = pd.read_parquet(config['data_paths'][f'y_train_{variante}']).values.ravel()
    y_test = pd.read_parquet(config['data_paths'][f'y_test_{variante}']).values.ravel()
    
    if X_train is None or X_test is None:
        print(f"Skipping variant {variante} due to memory issues.")
        continue
    
    # Reducir uso de memoria
    X_train = reduce_mem_usage(X_train)
    X_test = reduce_mem_usage(X_test)
    
# Crear pipeline con imputación de valores faltantes, PCA y selección de características
    pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy='mean')),  # Imputar valores faltantes con la media
        ('pca', PCA(n_components=0.95)),  # Reducir dimensionalidad manteniendo el 95% de la varianza
        ('selector', SelectKBest(f_classif, k=100))  # Selección de las 100 mejores características
    ])
    
    # Transformar los datos de entrenamiento
    try:
        X_train_reduced = pipeline.fit_transform(X_train, y_train)
        X_test_reduced = pipeline.transform(X_test)
    except MemoryError:
        print(f"Memory error during feature selection for variant {variante}. Skipping.")
        continue
    
    
     # Convertir a DataFrame y limpiar nombres de las columnas
    X_train_reduced = pd.DataFrame(X_train_reduced, columns=[f"feature_{i}" for i in range(X_train_reduced.shape[1])])
    X_test_reduced = pd.DataFrame(X_test_reduced, columns=[f"feature_{i}" for i in range(X_test_reduced.shape[1])])


    # Limpiar nombres de las columnas
    X_train_reduced = clean_column_names(X_train_reduced)
    X_test_reduced = clean_column_names(X_test_reduced)

    # Optimización de uso de memoria
    X_train_reduced = X_train_reduced.astype('float32')
    X_test_reduced = X_test_reduced.astype('float32')

# Configuración de FLAML AutoML
    automl = AutoML()
    automl_settings = {
    "time_budget": 1800,  # tiempo máximo de búsqueda en segundos
    "metric": 'accuracy',  # métrica de evaluación
    "task": 'classification',  # tarea de clasificación
    "log_file_name": "flaml_log.log",  # archivo de registro
    "n_jobs": 1,  # número de trabajos paralelos
    "mem_thres": 4 * 1024**3,  # umbral de memoria
    "ensemble": False,  # deshabilitar ensamblado
    "estimator_list": ["rf", "lgbm", "catboost", "extra_tree", "histgb"],  # modelos a considerar
    "fit_kwargs_by_estimator": {
        "rf": {},
        "lgbm": {},
        "catboost": {},
        "extra_tree": {},
        "histgb": {}
    }
}

# Entrenar el modelo con FLAML
    try:
        automl.fit(X_train=X_train_reduced, y_train=y_train, **automl_settings)
    except MemoryError:
        print(f"Memory error during model training for variant {variante}. Skipping.")
        continue


    # Hacer predicciones
    predictions = automl.predict(X_test_reduced)
    accuracy = accuracy_score(y_test, predictions)
    classification_rep = classification_report(y_test, predictions)
    print(f'FLAML Accuracy for {variante}: {accuracy}')
    print("Classification Report:")
    print(classification_rep)

  # Guardar el mejor modelo con la fecha
    model_filename = f'best_flaml_model_{variante}_{fecha_actual}.pkl'
    with open(model_filename, 'wb') as f:
        pickle.dump(automl, f)
        
    # Obtener y guardar la configuración del mejor modelo
    best_model_config = automl.best_config
    ensemble_status = automl_settings.get("ensemble", False)
    best_model_info = {
        "best_model_config": best_model_config,
        "ensemble": ensemble_status,
        "accuracy": accuracy,
        "classification_report": classification_rep,
        "date": fecha_actual
    }
    config_filename = f'best_flaml_model_config_{variante}_{fecha_actual}.json'
    with open(config_filename, 'w') as f:
        json.dump(best_model_info, f)

    # Almacenar resultados
    resultados[variante] = {
        "accuracy": accuracy,
        "classification_report": classification_rep,
        "model_filename": model_filename
    }

    # Calcular y graficar curvas ROC
    y_test_binarized = pd.get_dummies(y_test)
    y_score = automl.predict_proba(X_test_reduced)
    roc_auc = roc_auc_score(y_test_binarized, y_score, average=None)
    print(f'ROC AUC Score for each class ({variante}): {roc_auc}')

    # Crear PDF con las métricas y las curvas ROC
    with PdfPages(f'flaml_model_analysis_report_{variante}_{fecha_actual}.pdf') as pdf:
        plt.figure(figsize=(8, 6))
        plt.text(0.01, 0.05, str(classification_rep), {'fontsize': 10}, fontproperties='monospace')
        plt.axis('off')
        plt.title(f'Classification Report ({variante})')
        pdf.savefig()
        plt.close()

        plt.figure(figsize=(8, 6))
        for i in range(y_test_binarized.shape[1]):
            fpr, tpr, _ = roc_curve(y_test_binarized.iloc[:, i], y_score[:, i])
            plt.plot(fpr, tpr, lw=2, label=f'Class {i} (area = {roc_auc[i]:0.2f})')
        plt.plot([0, 1], [0, 1], 'k--', lw=2)
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.title(f'Receiver Operating Characteristic ({variante})')
        plt.legend(loc="lower right")
        pdf.savefig()
        plt.close()
# Out:
# Memory usage of dataframe is 1936.25 MB
# Memory usage after optimization is: 357.91 MB
# Decreased by 81.5%
# Memory usage of dataframe is 484.07 MB
# Memory usage after optimization is: 89.48 MB
# Decreased by 81.5%
# c:\Users\Administrador\Documents\Python Scripts\Tesis\tesisaustral\.venv\Lib\site-packages\sklearn\feature_selection\_univariate_selection.py:776: UserWarning: k=100 is greater than n_features=1. All the features will be returned.
#   warnings.warn(
# [flaml.automl.logger: 08-04 17:06:50] {1680} INFO - task = classification
# [flaml.automl.logger: 08-04 17:06:50] {1691} INFO - Evaluation method: holdout
# [flaml.automl.logger: 08-04 17:06:51] {1789} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 08-04 17:06:51] {1901} INFO - List of ML learners in AutoML Run: ['rf', 'lgbm', 'catboost', 'extra_tree', 'histgb']
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 0, current learner rf
# [flaml.automl.logger: 08-04 17:06:51] {2345} INFO - Estimated sufficient time budget=32282s. Estimated necessary time budget=34s.
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.4s,	estimator rf's best error=0.7232,	best estimator rf's best error=0.7232
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.5s,	estimator lgbm's best error=0.7232,	best estimator rf's best error=0.7232
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 2, current learner histgb
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.6s,	estimator histgb's best error=0.7228,	best estimator histgb's best error=0.7228
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 3, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.7s,	estimator lgbm's best error=0.7232,	best estimator histgb's best error=0.7228
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.7s,	estimator lgbm's best error=0.7232,	best estimator histgb's best error=0.7228
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 5, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.8s,	estimator extra_tree's best error=0.7232,	best estimator histgb's best error=0.7228
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 6, current learner rf
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 0.8s,	estimator rf's best error=0.7232,	best estimator histgb's best error=0.7228
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 7, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 1.0s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 8, current learner rf
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 1.1s,	estimator rf's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 9, current learner rf
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 1.1s,	estimator rf's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 1.3s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 11, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:51] {2392} INFO -  at 1.3s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:51] {2219} INFO - iteration 12, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.4s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 13, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.4s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.5s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 15, current learner histgb
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.5s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 16, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.6s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 17, current learner histgb
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.6s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 18, current learner rf
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.8s,	estimator rf's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 19, current learner histgb
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.8s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 20, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 1.9s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 21, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 2.0s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 22, current learner rf
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 2.1s,	estimator rf's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 2.2s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 24, current learner histgb
# [flaml.automl.logger: 08-04 17:06:52] {2392} INFO -  at 2.2s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:52] {2219} INFO - iteration 25, current learner histgb
# [flaml.automl.logger: 08-04 17:06:53] {2392} INFO -  at 2.4s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:53] {2219} INFO - iteration 26, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:53] {2392} INFO -  at 2.9s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:53] {2219} INFO - iteration 27, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:53] {2392} INFO -  at 3.0s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:53] {2219} INFO - iteration 28, current learner histgb
# [flaml.automl.logger: 08-04 17:06:53] {2392} INFO -  at 3.0s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:53] {2219} INFO - iteration 29, current learner histgb
# [flaml.automl.logger: 08-04 17:06:53] {2392} INFO -  at 3.0s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:53] {2219} INFO - iteration 30, current learner rf
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 3.4s,	estimator rf's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 31, current learner rf
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 3.6s,	estimator rf's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 32, current learner rf
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 3.8s,	estimator rf's best error=0.7229,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 33, current learner histgb
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 3.8s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 4.0s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 35, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 4.1s,	estimator extra_tree's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 36, current learner histgb
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 4.2s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 37, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:54] {2392} INFO -  at 4.3s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:54] {2219} INFO - iteration 38, current learner histgb
# [flaml.automl.logger: 08-04 17:06:55] {2392} INFO -  at 4.4s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:55] {2219} INFO - iteration 39, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:55] {2392} INFO -  at 4.5s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:55] {2219} INFO - iteration 40, current learner histgb
# [flaml.automl.logger: 08-04 17:06:55] {2392} INFO -  at 4.9s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:55] {2219} INFO - iteration 41, current learner histgb
# [flaml.automl.logger: 08-04 17:06:55] {2392} INFO -  at 5.2s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:55] {2219} INFO - iteration 42, current learner rf
# [flaml.automl.logger: 08-04 17:06:56] {2392} INFO -  at 5.6s,	estimator rf's best error=0.7229,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:56] {2219} INFO - iteration 43, current learner histgb
# [flaml.automl.logger: 08-04 17:06:56] {2392} INFO -  at 5.7s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:56] {2219} INFO - iteration 44, current learner histgb
# [flaml.automl.logger: 08-04 17:06:56] {2392} INFO -  at 5.9s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:56] {2219} INFO - iteration 45, current learner histgb
# [flaml.automl.logger: 08-04 17:06:56] {2392} INFO -  at 6.0s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:56] {2219} INFO - iteration 46, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:57] {2392} INFO -  at 7.3s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:57] {2219} INFO - iteration 47, current learner histgb
# [flaml.automl.logger: 08-04 17:06:58] {2392} INFO -  at 7.5s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:58] {2219} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 08-04 17:06:59] {2392} INFO -  at 8.4s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:59] {2219} INFO - iteration 49, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:59] {2392} INFO -  at 8.4s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:59] {2219} INFO - iteration 50, current learner histgb
# [flaml.automl.logger: 08-04 17:06:59] {2392} INFO -  at 8.6s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:59] {2219} INFO - iteration 51, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:59] {2392} INFO -  at 8.7s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:59] {2219} INFO - iteration 52, current learner extra_tree
# [flaml.automl.logger: 08-04 17:06:59] {2392} INFO -  at 8.8s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:06:59] {2219} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:00] {2392} INFO -  at 10.0s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:00] {2219} INFO - iteration 54, current learner rf
# [flaml.automl.logger: 08-04 17:07:01] {2392} INFO -  at 10.4s,	estimator rf's best error=0.7229,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:01] {2219} INFO - iteration 55, current learner histgb
# [flaml.automl.logger: 08-04 17:07:01] {2392} INFO -  at 11.0s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:01] {2219} INFO - iteration 56, current learner catboost
# [flaml.automl.logger: 08-04 17:07:04] {2392} INFO -  at 13.5s,	estimator catboost's best error=0.7240,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:04] {2219} INFO - iteration 57, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:05] {2392} INFO -  at 14.6s,	estimator lgbm's best error=0.7226,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:05] {2219} INFO - iteration 58, current learner catboost
# [flaml.automl.logger: 08-04 17:07:17] {2392} INFO -  at 26.5s,	estimator catboost's best error=0.7232,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:17] {2219} INFO - iteration 59, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:17] {2392} INFO -  at 26.7s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:17] {2219} INFO - iteration 60, current learner rf
# [flaml.automl.logger: 08-04 17:07:19] {2392} INFO -  at 28.6s,	estimator rf's best error=0.7227,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:19] {2219} INFO - iteration 61, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:19] {2392} INFO -  at 28.9s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7226
# [flaml.automl.logger: 08-04 17:07:19] {2219} INFO - iteration 62, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:20] {2392} INFO -  at 30.1s,	estimator lgbm's best error=0.7223,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:20] {2219} INFO - iteration 63, current learner histgb
# [flaml.automl.logger: 08-04 17:07:21] {2392} INFO -  at 30.8s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:21] {2219} INFO - iteration 64, current learner histgb
# [flaml.automl.logger: 08-04 17:07:22] {2392} INFO -  at 31.4s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:22] {2219} INFO - iteration 65, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:23] {2392} INFO -  at 32.4s,	estimator lgbm's best error=0.7223,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:23] {2219} INFO - iteration 66, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:23] {2392} INFO -  at 32.8s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:23] {2219} INFO - iteration 67, current learner histgb
# [flaml.automl.logger: 08-04 17:07:23] {2392} INFO -  at 33.3s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:23] {2219} INFO - iteration 68, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:24] {2392} INFO -  at 34.0s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:24] {2219} INFO - iteration 69, current learner rf
# [flaml.automl.logger: 08-04 17:07:26] {2392} INFO -  at 36.0s,	estimator rf's best error=0.7223,	best estimator rf's best error=0.7223
# [flaml.automl.logger: 08-04 17:07:26] {2219} INFO - iteration 70, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:27] {2392} INFO -  at 37.2s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:27] {2219} INFO - iteration 71, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:28] {2392} INFO -  at 38.3s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:28] {2219} INFO - iteration 72, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:30] {2392} INFO -  at 39.4s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:30] {2219} INFO - iteration 73, current learner histgb
# [flaml.automl.logger: 08-04 17:07:30] {2392} INFO -  at 40.3s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:30] {2219} INFO - iteration 74, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:32] {2392} INFO -  at 41.9s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:32] {2219} INFO - iteration 75, current learner histgb
# [flaml.automl.logger: 08-04 17:07:33] {2392} INFO -  at 42.7s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:33] {2219} INFO - iteration 76, current learner rf
# [flaml.automl.logger: 08-04 17:07:40] {2392} INFO -  at 50.1s,	estimator rf's best error=0.7223,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:40] {2219} INFO - iteration 77, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:41] {2392} INFO -  at 50.7s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:41] {2219} INFO - iteration 78, current learner histgb
# [flaml.automl.logger: 08-04 17:07:41] {2392} INFO -  at 51.2s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:41] {2219} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:44] {2392} INFO -  at 54.3s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:44] {2219} INFO - iteration 80, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:46] {2392} INFO -  at 56.1s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:46] {2219} INFO - iteration 81, current learner histgb
# [flaml.automl.logger: 08-04 17:07:47] {2392} INFO -  at 56.7s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:47] {2219} INFO - iteration 82, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:48] {2392} INFO -  at 57.6s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:48] {2219} INFO - iteration 83, current learner histgb
# [flaml.automl.logger: 08-04 17:07:49] {2392} INFO -  at 58.5s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:49] {2219} INFO - iteration 84, current learner histgb
# [flaml.automl.logger: 08-04 17:07:49] {2392} INFO -  at 59.0s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:49] {2219} INFO - iteration 85, current learner histgb
# [flaml.automl.logger: 08-04 17:07:50] {2392} INFO -  at 60.0s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:50] {2219} INFO - iteration 86, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:51] {2392} INFO -  at 60.4s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:51] {2219} INFO - iteration 87, current learner histgb
# [flaml.automl.logger: 08-04 17:07:51] {2392} INFO -  at 61.1s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:51] {2219} INFO - iteration 88, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:53] {2392} INFO -  at 62.5s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:53] {2219} INFO - iteration 89, current learner lgbm
# [flaml.automl.logger: 08-04 17:07:54] {2392} INFO -  at 63.7s,	estimator lgbm's best error=0.7215,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:54] {2219} INFO - iteration 90, current learner histgb
# [flaml.automl.logger: 08-04 17:07:54] {2392} INFO -  at 64.2s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:54] {2219} INFO - iteration 91, current learner catboost
# [flaml.automl.logger: 08-04 17:07:55] {2392} INFO -  at 65.1s,	estimator catboost's best error=0.7232,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:55] {2219} INFO - iteration 92, current learner histgb
# [flaml.automl.logger: 08-04 17:07:56] {2392} INFO -  at 66.2s,	estimator histgb's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:56] {2219} INFO - iteration 93, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:57] {2392} INFO -  at 67.1s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:57] {2219} INFO - iteration 94, current learner extra_tree
# [flaml.automl.logger: 08-04 17:07:58] {2392} INFO -  at 67.5s,	estimator extra_tree's best error=0.7228,	best estimator lgbm's best error=0.7215
# [flaml.automl.logger: 08-04 17:07:58] {2219} INFO - iteration 95, current learner rf
# [flaml.automl.logger: 08-04 17:08:01] {2392} INFO -  at 70.7s,	estimator rf's best error=0.7195,	best estimator rf's best error=0.7195
# [flaml.automl.logger: 08-04 17:08:01] {2219} INFO - iteration 96, current learner histgb
# [flaml.automl.logger: 08-04 17:08:01] {2392} INFO -  at 71.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7195
# [flaml.automl.logger: 08-04 17:08:01] {2219} INFO - iteration 97, current learner lgbm
# [flaml.automl.logger: 08-04 17:08:03] {2392} INFO -  at 72.7s,	estimator lgbm's best error=0.7212,	best estimator rf's best error=0.7195
# [flaml.automl.logger: 08-04 17:08:03] {2219} INFO - iteration 98, current learner extra_tree
# [flaml.automl.logger: 08-04 17:08:03] {2392} INFO -  at 73.0s,	estimator extra_tree's best error=0.7228,	best estimator rf's best error=0.7195
# [flaml.automl.logger: 08-04 17:08:03] {2219} INFO - iteration 99, current learner rf
# [flaml.automl.logger: 08-04 17:08:09] {2392} INFO -  at 78.9s,	estimator rf's best error=0.7195,	best estimator rf's best error=0.7195
# [flaml.automl.logger: 08-04 17:08:09] {2219} INFO - iteration 100, current learner rf
# [flaml.automl.logger: 08-04 17:08:13] {2392} INFO -  at 82.4s,	estimator rf's best error=0.7189,	best estimator rf's best error=0.7189
# [flaml.automl.logger: 08-04 17:08:13] {2219} INFO - iteration 101, current learner histgb
# [flaml.automl.logger: 08-04 17:08:13] {2392} INFO -  at 82.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7189
# [flaml.automl.logger: 08-04 17:08:13] {2219} INFO - iteration 102, current learner catboost
# [flaml.automl.logger: 08-04 17:08:24] {2392} INFO -  at 93.4s,	estimator catboost's best error=0.7232,	best estimator rf's best error=0.7189
# [flaml.automl.logger: 08-04 17:08:24] {2219} INFO - iteration 103, current learner rf
# [flaml.automl.logger: 08-04 17:08:36] {2392} INFO -  at 105.5s,	estimator rf's best error=0.7189,	best estimator rf's best error=0.7189
# [flaml.automl.logger: 08-04 17:08:36] {2219} INFO - iteration 104, current learner histgb
# [flaml.automl.logger: 08-04 17:08:36] {2392} INFO -  at 106.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7189
# [flaml.automl.logger: 08-04 17:08:36] {2219} INFO - iteration 105, current learner rf
# [flaml.automl.logger: 08-04 17:08:40] {2392} INFO -  at 109.8s,	estimator rf's best error=0.7175,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:40] {2219} INFO - iteration 106, current learner histgb
# [flaml.automl.logger: 08-04 17:08:41] {2392} INFO -  at 110.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:41] {2219} INFO - iteration 107, current learner histgb
# [flaml.automl.logger: 08-04 17:08:41] {2392} INFO -  at 111.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:41] {2219} INFO - iteration 108, current learner rf
# [flaml.automl.logger: 08-04 17:08:46] {2392} INFO -  at 116.1s,	estimator rf's best error=0.7175,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:46] {2219} INFO - iteration 109, current learner histgb
# [flaml.automl.logger: 08-04 17:08:47] {2392} INFO -  at 116.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:47] {2219} INFO - iteration 110, current learner histgb
# [flaml.automl.logger: 08-04 17:08:48] {2392} INFO -  at 117.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:48] {2219} INFO - iteration 111, current learner rf
# [flaml.automl.logger: 08-04 17:08:55] {2392} INFO -  at 124.7s,	estimator rf's best error=0.7175,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:55] {2219} INFO - iteration 112, current learner histgb
# [flaml.automl.logger: 08-04 17:08:55] {2392} INFO -  at 125.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:55] {2219} INFO - iteration 113, current learner histgb
# [flaml.automl.logger: 08-04 17:08:57] {2392} INFO -  at 126.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:57] {2219} INFO - iteration 114, current learner histgb
# [flaml.automl.logger: 08-04 17:08:58] {2392} INFO -  at 127.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7175
# [flaml.automl.logger: 08-04 17:08:58] {2219} INFO - iteration 115, current learner rf
# [flaml.automl.logger: 08-04 17:09:04] {2392} INFO -  at 133.4s,	estimator rf's best error=0.7168,	best estimator rf's best error=0.7168
# [flaml.automl.logger: 08-04 17:09:04] {2219} INFO - iteration 116, current learner rf
# [flaml.automl.logger: 08-04 17:09:13] {2392} INFO -  at 142.7s,	estimator rf's best error=0.7167,	best estimator rf's best error=0.7167
# [flaml.automl.logger: 08-04 17:09:13] {2219} INFO - iteration 117, current learner histgb
# [flaml.automl.logger: 08-04 17:09:13] {2392} INFO -  at 143.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7167
# [flaml.automl.logger: 08-04 17:09:13] {2219} INFO - iteration 118, current learner extra_tree
# [flaml.automl.logger: 08-04 17:09:14] {2392} INFO -  at 144.1s,	estimator extra_tree's best error=0.7228,	best estimator rf's best error=0.7167
# [flaml.automl.logger: 08-04 17:09:14] {2219} INFO - iteration 119, current learner rf
# [flaml.automl.logger: 08-04 17:09:20] {2392} INFO -  at 149.4s,	estimator rf's best error=0.7166,	best estimator rf's best error=0.7166
# [flaml.automl.logger: 08-04 17:09:20] {2219} INFO - iteration 120, current learner lgbm
# [flaml.automl.logger: 08-04 17:09:21] {2392} INFO -  at 150.7s,	estimator lgbm's best error=0.7212,	best estimator rf's best error=0.7166
# [flaml.automl.logger: 08-04 17:09:21] {2219} INFO - iteration 121, current learner rf
# [flaml.automl.logger: 08-04 17:09:29] {2392} INFO -  at 158.5s,	estimator rf's best error=0.7166,	best estimator rf's best error=0.7166
# [flaml.automl.logger: 08-04 17:09:29] {2219} INFO - iteration 122, current learner histgb
# [flaml.automl.logger: 08-04 17:09:29] {2392} INFO -  at 159.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7166
# [flaml.automl.logger: 08-04 17:09:29] {2219} INFO - iteration 123, current learner catboost
# [flaml.automl.logger: 08-04 17:09:30] {2392} INFO -  at 159.9s,	estimator catboost's best error=0.7232,	best estimator rf's best error=0.7166
# [flaml.automl.logger: 08-04 17:09:30] {2219} INFO - iteration 124, current learner rf
# [flaml.automl.logger: 08-04 17:09:37] {2392} INFO -  at 166.7s,	estimator rf's best error=0.7150,	best estimator rf's best error=0.7150
# [flaml.automl.logger: 08-04 17:09:37] {2219} INFO - iteration 125, current learner rf
# [flaml.automl.logger: 08-04 17:09:47] {2392} INFO -  at 176.8s,	estimator rf's best error=0.7150,	best estimator rf's best error=0.7150
# [flaml.automl.logger: 08-04 17:09:47] {2219} INFO - iteration 126, current learner rf
# [flaml.automl.logger: 08-04 17:09:52] {2392} INFO -  at 182.0s,	estimator rf's best error=0.7105,	best estimator rf's best error=0.7105
# [flaml.automl.logger: 08-04 17:09:52] {2219} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 08-04 17:09:57] {2392} INFO -  at 186.9s,	estimator rf's best error=0.7105,	best estimator rf's best error=0.7105
# [flaml.automl.logger: 08-04 17:09:57] {2219} INFO - iteration 128, current learner rf
# [flaml.automl.logger: 08-04 17:10:06] {2392} INFO -  at 195.7s,	estimator rf's best error=0.7086,	best estimator rf's best error=0.7086
# [flaml.automl.logger: 08-04 17:10:06] {2219} INFO - iteration 129, current learner histgb
# [flaml.automl.logger: 08-04 17:10:07] {2392} INFO -  at 197.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7086
# [flaml.automl.logger: 08-04 17:10:07] {2219} INFO - iteration 130, current learner rf
# [flaml.automl.logger: 08-04 17:10:23] {2392} INFO -  at 212.9s,	estimator rf's best error=0.7086,	best estimator rf's best error=0.7086
# [flaml.automl.logger: 08-04 17:10:23] {2219} INFO - iteration 131, current learner rf
# [flaml.automl.logger: 08-04 17:10:41] {2392} INFO -  at 230.5s,	estimator rf's best error=0.7071,	best estimator rf's best error=0.7071
# [flaml.automl.logger: 08-04 17:10:41] {2219} INFO - iteration 132, current learner histgb
# [flaml.automl.logger: 08-04 17:10:42] {2392} INFO -  at 231.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.7071
# [flaml.automl.logger: 08-04 17:10:42] {2219} INFO - iteration 133, current learner rf
# [flaml.automl.logger: 08-04 17:10:54] {2392} INFO -  at 244.3s,	estimator rf's best error=0.7071,	best estimator rf's best error=0.7071
# [flaml.automl.logger: 08-04 17:10:54] {2219} INFO - iteration 134, current learner rf
# [flaml.automl.logger: 08-04 17:11:49] {2392} INFO -  at 298.8s,	estimator rf's best error=0.6995,	best estimator rf's best error=0.6995
# [flaml.automl.logger: 08-04 17:11:49] {2219} INFO - iteration 135, current learner histgb
# [flaml.automl.logger: 08-04 17:11:52] {2392} INFO -  at 302.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6995
# [flaml.automl.logger: 08-04 17:11:52] {2219} INFO - iteration 136, current learner histgb
# [flaml.automl.logger: 08-04 17:11:53] {2392} INFO -  at 303.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6995
# [flaml.automl.logger: 08-04 17:11:53] {2219} INFO - iteration 137, current learner histgb
# [flaml.automl.logger: 08-04 17:11:55] {2392} INFO -  at 305.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6995
# [flaml.automl.logger: 08-04 17:11:55] {2219} INFO - iteration 138, current learner rf
# [flaml.automl.logger: 08-04 17:13:49] {2392} INFO -  at 419.3s,	estimator rf's best error=0.6959,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:49] {2219} INFO - iteration 139, current learner histgb
# [flaml.automl.logger: 08-04 17:13:51] {2392} INFO -  at 420.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:51] {2219} INFO - iteration 140, current learner extra_tree
# [flaml.automl.logger: 08-04 17:13:51] {2392} INFO -  at 421.2s,	estimator extra_tree's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:51] {2219} INFO - iteration 141, current learner histgb
# [flaml.automl.logger: 08-04 17:13:53] {2392} INFO -  at 422.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:53] {2219} INFO - iteration 142, current learner histgb
# [flaml.automl.logger: 08-04 17:13:54] {2392} INFO -  at 424.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:54] {2219} INFO - iteration 143, current learner histgb
# [flaml.automl.logger: 08-04 17:13:55] {2392} INFO -  at 425.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:55] {2219} INFO - iteration 144, current learner histgb
# [flaml.automl.logger: 08-04 17:13:56] {2392} INFO -  at 426.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:56] {2219} INFO - iteration 145, current learner histgb
# [flaml.automl.logger: 08-04 17:13:58] {2392} INFO -  at 427.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:13:58] {2219} INFO - iteration 146, current learner rf
# [flaml.automl.logger: 08-04 17:14:31] {2392} INFO -  at 460.6s,	estimator rf's best error=0.6959,	best estimator rf's best error=0.6959
# [flaml.automl.logger: 08-04 17:14:31] {2219} INFO - iteration 147, current learner rf
# [flaml.automl.logger: 08-04 17:15:37] {2392} INFO -  at 527.2s,	estimator rf's best error=0.6933,	best estimator rf's best error=0.6933
# [flaml.automl.logger: 08-04 17:15:37] {2219} INFO - iteration 148, current learner rf
# [flaml.automl.logger: 08-04 17:16:05] {2392} INFO -  at 554.5s,	estimator rf's best error=0.6933,	best estimator rf's best error=0.6933
# [flaml.automl.logger: 08-04 17:16:05] {2219} INFO - iteration 149, current learner rf
# [flaml.automl.logger: 08-04 17:16:38] {2392} INFO -  at 587.5s,	estimator rf's best error=0.6929,	best estimator rf's best error=0.6929
# [flaml.automl.logger: 08-04 17:16:38] {2219} INFO - iteration 150, current learner rf
# [flaml.automl.logger: 08-04 17:16:55] {2392} INFO -  at 605.2s,	estimator rf's best error=0.6929,	best estimator rf's best error=0.6929
# [flaml.automl.logger: 08-04 17:16:55] {2219} INFO - iteration 151, current learner rf
# [flaml.automl.logger: 08-04 17:17:34] {2392} INFO -  at 643.8s,	estimator rf's best error=0.6929,	best estimator rf's best error=0.6929
# [flaml.automl.logger: 08-04 17:17:34] {2219} INFO - iteration 152, current learner histgb
# [flaml.automl.logger: 08-04 17:17:35] {2392} INFO -  at 645.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6929
# [flaml.automl.logger: 08-04 17:17:35] {2219} INFO - iteration 153, current learner histgb
# [flaml.automl.logger: 08-04 17:17:36] {2392} INFO -  at 645.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6929
# [flaml.automl.logger: 08-04 17:17:36] {2219} INFO - iteration 154, current learner rf
# [flaml.automl.logger: 08-04 17:18:21] {2392} INFO -  at 691.2s,	estimator rf's best error=0.6929,	best estimator rf's best error=0.6929
# [flaml.automl.logger: 08-04 17:18:21] {2219} INFO - iteration 155, current learner rf
# [flaml.automl.logger: 08-04 17:19:22] {2392} INFO -  at 751.6s,	estimator rf's best error=0.6918,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:19:22] {2219} INFO - iteration 156, current learner histgb
# [flaml.automl.logger: 08-04 17:19:22] {2392} INFO -  at 752.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:19:22] {2219} INFO - iteration 157, current learner histgb
# [flaml.automl.logger: 08-04 17:19:23] {2392} INFO -  at 753.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:19:23] {2219} INFO - iteration 158, current learner catboost
# [flaml.automl.logger: 08-04 17:19:35] {2392} INFO -  at 765.1s,	estimator catboost's best error=0.7232,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:19:35] {2219} INFO - iteration 159, current learner histgb
# [flaml.automl.logger: 08-04 17:19:36] {2392} INFO -  at 766.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:19:36] {2219} INFO - iteration 160, current learner histgb
# [flaml.automl.logger: 08-04 17:19:37] {2392} INFO -  at 766.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:19:37] {2219} INFO - iteration 161, current learner rf
# [flaml.automl.logger: 08-04 17:20:31] {2392} INFO -  at 821.3s,	estimator rf's best error=0.6918,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:31] {2219} INFO - iteration 162, current learner histgb
# [flaml.automl.logger: 08-04 17:20:32] {2392} INFO -  at 821.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:32] {2219} INFO - iteration 163, current learner histgb
# [flaml.automl.logger: 08-04 17:20:34] {2392} INFO -  at 824.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:34] {2219} INFO - iteration 164, current learner histgb
# [flaml.automl.logger: 08-04 17:20:35] {2392} INFO -  at 824.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:35] {2219} INFO - iteration 165, current learner extra_tree
# [flaml.automl.logger: 08-04 17:20:36] {2392} INFO -  at 825.6s,	estimator extra_tree's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:36] {2219} INFO - iteration 166, current learner histgb
# [flaml.automl.logger: 08-04 17:20:37] {2392} INFO -  at 826.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:37] {2219} INFO - iteration 167, current learner histgb
# [flaml.automl.logger: 08-04 17:20:38] {2392} INFO -  at 828.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:38] {2219} INFO - iteration 168, current learner histgb
# [flaml.automl.logger: 08-04 17:20:39] {2392} INFO -  at 828.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6918
# [flaml.automl.logger: 08-04 17:20:39] {2219} INFO - iteration 169, current learner rf
# [flaml.automl.logger: 08-04 17:22:57] {2392} INFO -  at 966.9s,	estimator rf's best error=0.6912,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:22:57] {2219} INFO - iteration 170, current learner rf
# [flaml.automl.logger: 08-04 17:24:46] {2392} INFO -  at 1076.2s,	estimator rf's best error=0.6912,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:24:46] {2219} INFO - iteration 171, current learner rf
# [flaml.automl.logger: 08-04 17:26:39] {2392} INFO -  at 1189.3s,	estimator rf's best error=0.6912,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:39] {2219} INFO - iteration 172, current learner histgb
# [flaml.automl.logger: 08-04 17:26:40] {2392} INFO -  at 1189.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:40] {2219} INFO - iteration 173, current learner histgb
# [flaml.automl.logger: 08-04 17:26:41] {2392} INFO -  at 1190.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:41] {2219} INFO - iteration 174, current learner histgb
# [flaml.automl.logger: 08-04 17:26:41] {2392} INFO -  at 1191.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:41] {2219} INFO - iteration 175, current learner histgb
# [flaml.automl.logger: 08-04 17:26:42] {2392} INFO -  at 1191.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:42] {2219} INFO - iteration 176, current learner histgb
# [flaml.automl.logger: 08-04 17:26:42] {2392} INFO -  at 1192.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:42] {2219} INFO - iteration 177, current learner histgb
# [flaml.automl.logger: 08-04 17:26:43] {2392} INFO -  at 1192.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:43] {2219} INFO - iteration 178, current learner histgb
# [flaml.automl.logger: 08-04 17:26:43] {2392} INFO -  at 1192.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:43] {2219} INFO - iteration 179, current learner histgb
# [flaml.automl.logger: 08-04 17:26:43] {2392} INFO -  at 1192.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:43] {2219} INFO - iteration 180, current learner histgb
# [flaml.automl.logger: 08-04 17:26:43] {2392} INFO -  at 1193.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:43] {2219} INFO - iteration 181, current learner histgb
# [flaml.automl.logger: 08-04 17:26:43] {2392} INFO -  at 1193.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:43] {2219} INFO - iteration 182, current learner histgb
# [flaml.automl.logger: 08-04 17:26:43] {2392} INFO -  at 1193.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:43] {2219} INFO - iteration 183, current learner histgb
# [flaml.automl.logger: 08-04 17:26:44] {2392} INFO -  at 1193.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:44] {2219} INFO - iteration 184, current learner histgb
# [flaml.automl.logger: 08-04 17:26:44] {2392} INFO -  at 1193.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:44] {2219} INFO - iteration 185, current learner histgb
# [flaml.automl.logger: 08-04 17:26:44] {2392} INFO -  at 1193.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:44] {2219} INFO - iteration 186, current learner histgb
# [flaml.automl.logger: 08-04 17:26:44] {2392} INFO -  at 1194.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:44] {2219} INFO - iteration 187, current learner histgb
# [flaml.automl.logger: 08-04 17:26:46] {2392} INFO -  at 1196.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6912
# [flaml.automl.logger: 08-04 17:26:46] {2219} INFO - iteration 188, current learner rf
# [flaml.automl.logger: 08-04 17:28:23] {2392} INFO -  at 1292.6s,	estimator rf's best error=0.6908,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:23] {2219} INFO - iteration 189, current learner histgb
# [flaml.automl.logger: 08-04 17:28:23] {2392} INFO -  at 1293.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:23] {2219} INFO - iteration 190, current learner histgb
# [flaml.automl.logger: 08-04 17:28:25] {2392} INFO -  at 1295.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:25] {2219} INFO - iteration 191, current learner extra_tree
# [flaml.automl.logger: 08-04 17:28:26] {2392} INFO -  at 1295.5s,	estimator extra_tree's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:26] {2219} INFO - iteration 192, current learner histgb
# [flaml.automl.logger: 08-04 17:28:26] {2392} INFO -  at 1296.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:26] {2219} INFO - iteration 193, current learner histgb
# [flaml.automl.logger: 08-04 17:28:27] {2392} INFO -  at 1296.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:27] {2219} INFO - iteration 194, current learner histgb
# [flaml.automl.logger: 08-04 17:28:28] {2392} INFO -  at 1297.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:28] {2219} INFO - iteration 195, current learner histgb
# [flaml.automl.logger: 08-04 17:28:28] {2392} INFO -  at 1298.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:28:28] {2219} INFO - iteration 196, current learner rf
# [flaml.automl.logger: 08-04 17:30:27] {2392} INFO -  at 1416.8s,	estimator rf's best error=0.6908,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:30:27] {2219} INFO - iteration 197, current learner histgb
# [flaml.automl.logger: 08-04 17:30:28] {2392} INFO -  at 1417.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:30:28] {2219} INFO - iteration 198, current learner histgb
# [flaml.automl.logger: 08-04 17:30:29] {2392} INFO -  at 1418.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:30:29] {2219} INFO - iteration 199, current learner histgb
# [flaml.automl.logger: 08-04 17:30:30] {2392} INFO -  at 1420.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:30:30] {2219} INFO - iteration 200, current learner histgb
# [flaml.automl.logger: 08-04 17:30:31] {2392} INFO -  at 1421.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:30:31] {2219} INFO - iteration 201, current learner rf
# [flaml.automl.logger: 08-04 17:35:22] {2392} INFO -  at 1711.9s,	estimator rf's best error=0.6908,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:35:22] {2219} INFO - iteration 202, current learner histgb
# [flaml.automl.logger: 08-04 17:35:23] {2392} INFO -  at 1713.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:35:23] {2219} INFO - iteration 203, current learner histgb
# [flaml.automl.logger: 08-04 17:35:24] {2392} INFO -  at 1714.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:35:24] {2219} INFO - iteration 204, current learner histgb
# [flaml.automl.logger: 08-04 17:35:25] {2392} INFO -  at 1715.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6908
# [flaml.automl.logger: 08-04 17:35:25] {2219} INFO - iteration 205, current learner histgb
# ...
# [flaml.automl.logger: 08-04 19:42:33] {2219} INFO - iteration 222, current learner histgb
# [flaml.automl.logger: 08-04 19:42:34] {2392} INFO -  at 1552.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:34] {2219} INFO - iteration 223, current learner histgb
# [flaml.automl.logger: 08-04 19:42:36] {2392} INFO -  at 1555.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:36] {2219} INFO - iteration 224, current learner lgbm
# [flaml.automl.logger: 08-04 19:42:39] {2392} INFO -  at 1558.0s,	estimator lgbm's best error=0.7203,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:39] {2219} INFO - iteration 225, current learner histgb
# [flaml.automl.logger: 08-04 19:42:41] {2392} INFO -  at 1559.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:41] {2219} INFO - iteration 226, current learner histgb
# [flaml.automl.logger: 08-04 19:42:42] {2392} INFO -  at 1560.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:42] {2219} INFO - iteration 227, current learner histgb
# [flaml.automl.logger: 08-04 19:42:43] {2392} INFO -  at 1561.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:43] {2219} INFO - iteration 228, current learner histgb
# [flaml.automl.logger: 08-04 19:42:44] {2392} INFO -  at 1562.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:44] {2219} INFO - iteration 229, current learner histgb
# [flaml.automl.logger: 08-04 19:42:47] {2392} INFO -  at 1565.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:47] {2219} INFO - iteration 230, current learner histgb
# [flaml.automl.logger: 08-04 19:42:48] {2392} INFO -  at 1566.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:48] {2219} INFO - iteration 231, current learner histgb
# [flaml.automl.logger: 08-04 19:42:51] {2392} INFO -  at 1569.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:51] {2219} INFO - iteration 232, current learner histgb
# [flaml.automl.logger: 08-04 19:42:52] {2392} INFO -  at 1571.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:52] {2219} INFO - iteration 233, current learner histgb
# [flaml.automl.logger: 08-04 19:42:53] {2392} INFO -  at 1572.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:53] {2219} INFO - iteration 234, current learner histgb
# [flaml.automl.logger: 08-04 19:42:57] {2392} INFO -  at 1575.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:57] {2219} INFO - iteration 235, current learner histgb
# [flaml.automl.logger: 08-04 19:42:59] {2392} INFO -  at 1577.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:42:59] {2219} INFO - iteration 236, current learner histgb
# [flaml.automl.logger: 08-04 19:43:01] {2392} INFO -  at 1579.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:01] {2219} INFO - iteration 237, current learner histgb
# [flaml.automl.logger: 08-04 19:43:02] {2392} INFO -  at 1580.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:02] {2219} INFO - iteration 238, current learner histgb
# [flaml.automl.logger: 08-04 19:43:04] {2392} INFO -  at 1582.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:04] {2219} INFO - iteration 239, current learner histgb
# [flaml.automl.logger: 08-04 19:43:05] {2392} INFO -  at 1583.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:05] {2219} INFO - iteration 240, current learner histgb
# [flaml.automl.logger: 08-04 19:43:07] {2392} INFO -  at 1585.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:07] {2219} INFO - iteration 241, current learner lgbm
# [flaml.automl.logger: 08-04 19:43:39] {2392} INFO -  at 1618.1s,	estimator lgbm's best error=0.7203,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:39] {2219} INFO - iteration 242, current learner histgb
# [flaml.automl.logger: 08-04 19:43:41] {2392} INFO -  at 1619.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:41] {2219} INFO - iteration 243, current learner histgb
# [flaml.automl.logger: 08-04 19:43:42] {2392} INFO -  at 1621.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:42] {2219} INFO - iteration 244, current learner histgb
# [flaml.automl.logger: 08-04 19:43:45] {2392} INFO -  at 1623.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:45] {2219} INFO - iteration 245, current learner histgb
# [flaml.automl.logger: 08-04 19:43:46] {2392} INFO -  at 1624.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:46] {2219} INFO - iteration 246, current learner histgb
# [flaml.automl.logger: 08-04 19:43:47] {2392} INFO -  at 1625.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:47] {2219} INFO - iteration 247, current learner histgb
# [flaml.automl.logger: 08-04 19:43:48] {2392} INFO -  at 1626.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:48] {2219} INFO - iteration 248, current learner histgb
# [flaml.automl.logger: 08-04 19:43:50] {2392} INFO -  at 1628.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:50] {2219} INFO - iteration 249, current learner histgb
# [flaml.automl.logger: 08-04 19:43:51] {2392} INFO -  at 1629.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:51] {2219} INFO - iteration 250, current learner histgb
# [flaml.automl.logger: 08-04 19:43:52] {2392} INFO -  at 1630.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:43:52] {2219} INFO - iteration 251, current learner catboost
# [flaml.automl.logger: 08-04 19:44:00] {2392} INFO -  at 1638.9s,	estimator catboost's best error=0.7232,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:00] {2219} INFO - iteration 252, current learner histgb
# [flaml.automl.logger: 08-04 19:44:01] {2392} INFO -  at 1640.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:01] {2219} INFO - iteration 253, current learner histgb
# [flaml.automl.logger: 08-04 19:44:03] {2392} INFO -  at 1641.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:03] {2219} INFO - iteration 254, current learner histgb
# [flaml.automl.logger: 08-04 19:44:04] {2392} INFO -  at 1642.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:04] {2219} INFO - iteration 255, current learner lgbm
# [flaml.automl.logger: 08-04 19:44:06] {2392} INFO -  at 1644.2s,	estimator lgbm's best error=0.7203,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:06] {2219} INFO - iteration 256, current learner histgb
# [flaml.automl.logger: 08-04 19:44:07] {2392} INFO -  at 1646.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:07] {2219} INFO - iteration 257, current learner histgb
# [flaml.automl.logger: 08-04 19:44:08] {2392} INFO -  at 1647.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:08] {2219} INFO - iteration 258, current learner histgb
# [flaml.automl.logger: 08-04 19:44:10] {2392} INFO -  at 1648.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:10] {2219} INFO - iteration 259, current learner histgb
# [flaml.automl.logger: 08-04 19:44:11] {2392} INFO -  at 1649.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:11] {2219} INFO - iteration 260, current learner histgb
# [flaml.automl.logger: 08-04 19:44:12] {2392} INFO -  at 1650.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:12] {2219} INFO - iteration 261, current learner histgb
# [flaml.automl.logger: 08-04 19:44:13] {2392} INFO -  at 1651.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:13] {2219} INFO - iteration 262, current learner histgb
# [flaml.automl.logger: 08-04 19:44:14] {2392} INFO -  at 1652.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:14] {2219} INFO - iteration 263, current learner histgb
# [flaml.automl.logger: 08-04 19:44:14] {2392} INFO -  at 1653.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:14] {2219} INFO - iteration 264, current learner histgb
# [flaml.automl.logger: 08-04 19:44:21] {2392} INFO -  at 1660.1s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:21] {2219} INFO - iteration 265, current learner histgb
# [flaml.automl.logger: 08-04 19:44:36] {2392} INFO -  at 1674.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:36] {2219} INFO - iteration 266, current learner histgb
# [flaml.automl.logger: 08-04 19:44:39] {2392} INFO -  at 1677.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:39] {2219} INFO - iteration 267, current learner histgb
# [flaml.automl.logger: 08-04 19:44:41] {2392} INFO -  at 1679.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:41] {2219} INFO - iteration 268, current learner histgb
# [flaml.automl.logger: 08-04 19:44:47] {2392} INFO -  at 1685.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:47] {2219} INFO - iteration 269, current learner histgb
# [flaml.automl.logger: 08-04 19:44:53] {2392} INFO -  at 1691.4s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:53] {2219} INFO - iteration 270, current learner histgb
# [flaml.automl.logger: 08-04 19:44:59] {2392} INFO -  at 1697.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:44:59] {2219} INFO - iteration 271, current learner histgb
# [flaml.automl.logger: 08-04 19:45:00] {2392} INFO -  at 1698.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:00] {2219} INFO - iteration 272, current learner histgb
# [flaml.automl.logger: 08-04 19:45:08] {2392} INFO -  at 1706.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:08] {2219} INFO - iteration 273, current learner histgb
# [flaml.automl.logger: 08-04 19:45:09] {2392} INFO -  at 1707.6s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:09] {2219} INFO - iteration 274, current learner histgb
# [flaml.automl.logger: 08-04 19:45:14] {2392} INFO -  at 1712.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:14] {2219} INFO - iteration 275, current learner histgb
# [flaml.automl.logger: 08-04 19:45:15] {2392} INFO -  at 1713.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:15] {2219} INFO - iteration 276, current learner histgb
# [flaml.automl.logger: 08-04 19:45:16] {2392} INFO -  at 1714.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:16] {2219} INFO - iteration 277, current learner histgb
# [flaml.automl.logger: 08-04 19:45:17] {2392} INFO -  at 1715.5s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:17] {2219} INFO - iteration 278, current learner histgb
# [flaml.automl.logger: 08-04 19:45:20] {2392} INFO -  at 1718.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:20] {2219} INFO - iteration 279, current learner histgb
# [flaml.automl.logger: 08-04 19:45:26] {2392} INFO -  at 1725.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:26] {2219} INFO - iteration 280, current learner histgb
# [flaml.automl.logger: 08-04 19:45:28] {2392} INFO -  at 1726.9s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:28] {2219} INFO - iteration 281, current learner histgb
# [flaml.automl.logger: 08-04 19:45:29] {2392} INFO -  at 1727.8s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:29] {2219} INFO - iteration 282, current learner histgb
# [flaml.automl.logger: 08-04 19:45:35] {2392} INFO -  at 1733.2s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:35] {2219} INFO - iteration 283, current learner histgb
# [flaml.automl.logger: 08-04 19:45:56] {2392} INFO -  at 1754.7s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:45:56] {2219} INFO - iteration 284, current learner histgb
# [flaml.automl.logger: 08-04 19:46:08] {2392} INFO -  at 1767.0s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:46:08] {2219} INFO - iteration 285, current learner histgb
# [flaml.automl.logger: 08-04 19:46:53] {2392} INFO -  at 1811.3s,	estimator histgb's best error=0.7228,	best estimator rf's best error=0.6919
# [flaml.automl.logger: 08-04 19:50:01] {2628} INFO - retrain rf for 188.5s
# [flaml.automl.logger: 08-04 19:50:01] {2631} INFO - retrained model: RandomForestClassifier(criterion='entropy', max_features=1.0,
#                        max_leaf_nodes=32767, n_estimators=53, n_jobs=1,
#                        random_state=12032022)
# [flaml.automl.logger: 08-04 19:50:01] {1931} INFO - fit succeeded
# [flaml.automl.logger: 08-04 19:50:01] {1932} INFO - Time taken to find the best model: 1399.0919361114502
# FLAML Accuracy for Robust: 0.3152330996092705
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.21      0.14      0.17     14641
#            2       0.29      0.25      0.27     19033
#            3       0.24      0.21      0.22     22581
#            4       0.26      0.26      0.26     24493
#            5       0.41      0.56      0.48     31350
#
#     accuracy                           0.32    112098
#    macro avg       0.28      0.28      0.28    112098
# weighted avg       0.30      0.32      0.30    112098
#
# ROC AUC Score for each class (Robust): [0.60653434 0.62423348 0.55087585 0.5520506  0.68372868]

# %%
# Comparación de resultados entre variantes
print("Resultados de todas las variantes:")
for variante, resultado in resultados.items():
    print(f"Variante: {variante}")
    print(f"Accuracy: {resultado['accuracy']}")
    print(f"Model File: {resultado['model_filename']}")
    print(f"Classification Report:\n{resultado['classification_report']}")
# Out:
# Resultados de todas las variantes:
# Variante: No_Norm
# Accuracy: 0.31739192492283536
# Model File: best_flaml_model_No_Norm_20240804.pkl
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.23      0.12      0.15     14641
#            2       0.30      0.23      0.26     19033
#            3       0.24      0.20      0.22     22581
#            4       0.26      0.27      0.26     24493
#            5       0.40      0.59      0.48     31350
#
#     accuracy                           0.32    112098
#    macro avg       0.29      0.28      0.27    112098
# weighted avg       0.30      0.32      0.30    112098
#
# Variante: MinMax
# Accuracy: 0.31501008046530715
# Model File: best_flaml_model_MinMax_20240804.pkl
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.22      0.13      0.16     14641
#            2       0.29      0.24      0.26     19033
#            3       0.24      0.21      0.23     22581
#            4       0.26      0.27      0.26     24493
#            5       0.41      0.56      0.48     31350
#
#     accuracy                           0.32    112098
#    macro avg       0.28      0.28      0.28    112098
# weighted avg       0.30      0.32      0.30    112098
#
# Variante: Std
# Accuracy: 0.31673178825670395
# Model File: best_flaml_model_Std_20240804.pkl
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.22      0.13      0.16     14641
#            2       0.29      0.24      0.27     19033
#            3       0.24      0.21      0.23     22581
#            4       0.26      0.27      0.26     24493
#            5       0.42      0.56      0.48     31350
#
#     accuracy                           0.32    112098
#    macro avg       0.29      0.28      0.28    112098
# weighted avg       0.30      0.32      0.30    112098
#
# Variante: Maxabs
# Accuracy: 0.3167407090224625
# Model File: best_flaml_model_Maxabs_20240804.pkl
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.22      0.13      0.16     14641
#            2       0.29      0.24      0.27     19033
#            3       0.24      0.21      0.23     22581
#            4       0.26      0.27      0.26     24493
#            5       0.42      0.56      0.48     31350
#
#     accuracy                           0.32    112098
#    macro avg       0.29      0.28      0.28    112098
# weighted avg       0.30      0.32      0.30    112098
#
# Variante: Robust
# Accuracy: 0.3152330996092705
# Model File: best_flaml_model_Robust_20240804.pkl
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.21      0.14      0.17     14641
#            2       0.29      0.25      0.27     19033
#            3       0.24      0.21      0.22     22581
#            4       0.26      0.26      0.26     24493
#            5       0.41      0.56      0.48     31350
#
#     accuracy                           0.32    112098
#    macro avg       0.28      0.28      0.28    112098
# weighted avg       0.30      0.32      0.30    112098

# %%
# Nombre del archivo PDF con la fecha actual
pdf_filename = f'resultados_comparacion_{fecha_actual}.pdf'

# Crear un archivo PDF y escribir los resultados
with PdfPages(pdf_filename) as pdf:
    # Crear una nueva figura
    plt.figure(figsize=(8.5, 11))  # Tamaño A4
    plt.axis('off')
    
    # Título del PDF
    plt.text(0.5, 0.95, "Comparación de resultados entre variantes", fontsize=16, ha='center')
    
    # Escribir los resultados
    y_position = 0.85
    for variante, resultado in resultados.items():
        plt.text(0.5, y_position, f"Variante: {variante}", fontsize=12, ha='center')
        y_position -= 0.03  # Espacio después del nombre de la variante
        plt.text(0.5, y_position, f"Accuracy: {resultado['accuracy']}", fontsize=10, ha='center')
        y_position -= 0.03  # Espacio después del accuracy
        plt.text(0.5, y_position, f"Model File: {resultado['model_filename']}", fontsize=10, ha='center')
        y_position -= 0.03  # Espacio después del nombre del archivo

        # Escribir el informe de clasificación en múltiples líneas si es necesario
        lines = resultado['classification_report'].split('\n')
        for line in lines:
            plt.text(0.5, y_position, line, fontsize=8, ha='center')
            y_position -= 0.02  # Espacio entre líneas del informe de clasificación

        y_position -= 0.05  # Espacio adicional después del informe

        # Agregar un separador
        plt.text(0.5, y_position, '-'*80, fontsize=10, ha='center')
        y_position -= 0.03  # Espacio después del separador

        # Asegurarse de no escribir más allá de la página
        if y_position < 0.1:
            pdf.savefig()  # Guardar la página actual en el PDF
            plt.close()    # Cerrar la figura actual
            plt.figure(figsize=(8.5, 11))  # Nueva figura para nueva página
            plt.axis('off')
            y_position = 0.95  # Reiniciar la posición vertical

    pdf.savefig()  # Guardar la última página en el PDF
    plt.close()    # Cerrar la figura
